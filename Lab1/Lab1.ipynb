# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sales.csv')

# %%
df
# Out:
#        order_id                        name           ordered_at   price  \
# 0         10000    "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00   $3.50
# 1         10000    "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00   $3.50
# 2         10001          "SORBET" Raspberry  2018-01-01 12:14:54   $2.50
# 3         10001                         NaN  2018-01-01 12:14:54   $1.50
# 4         10001   "CONE" Dipped Waffle Cone  2018-01-01 12:14:54   $3.50
# ...         ...                         ...                  ...     ...
# 29917     18452  "ICE CREAM" Dulce De Leche  2018-06-26 03:56:13  $-1.50
# 29918     12889  "ICE CREAM" Dark Chocolate  2018-03-03 10:06:21   $4.00
# 29919     14526    "ICE CREAM" Peanut Fudge  2018-04-05 17:33:24   $3.50
# 29920     19589   "CONE" Dipped Waffle Cone  2018-07-20 09:10:01   $3.50
# 29921     19270       "ICE CREAM" Earl Gray  2018-07-13 09:20:21   $0.50
#
#        quantity line_total
# 0             3     $10.50
# 1             1      $3.50
# ...

# %%
# %matplotlib inline
df.head(10)
# Out:
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54  $2.50         2
# 3     10001                        NaN  2018-01-01 12:14:54  $1.50         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54  $3.50         1
# 5     10002            "SORBET" Lychee  2018-01-01 12:23:09  $3.00         1
# 6     10002                        NaN  2018-01-01 12:23:09  $3.00         3
# 7     10002      "ICE CREAM" Earl Gray  2018-01-01 12:23:09  $0.50         3
# 8     10003         "ICE CREAM" Matcha  2018-01-01 12:49:35  $1.50         3
# 9     10004     "BEVERAGE" Iced Coffee  2018-01-01 13:22:59  $2.50         2
#
#   line_total
# 0     $10.50
# 1      $3.50
# 2      $5.00
# 3      $1.50
# 4      $3.50
# 5      $3.00
# 6      $9.00
# ...

# %%
df.shape
# Out:
# (29922, 6)

# %%
df.size
# Out:
# 179532

# %%
len(df)
# Out:
# 29922

# %%
df.columns
# Out:
# Index(['order_id', 'name', 'ordered_at', 'price', 'quantity', 'line_total'], dtype='object')

# %%
df["name"]
# Out:
# 0          "ICE CREAM" Peanut Fudge
# 1          "ICE CREAM" Peanut Fudge
# 2                "SORBET" Raspberry
# 3                               NaN
# 4         "CONE" Dipped Waffle Cone
#                     ...
# 29917    "ICE CREAM" Dulce De Leche
# 29918    "ICE CREAM" Dark Chocolate
# 29919      "ICE CREAM" Peanut Fudge
# 29920     "CONE" Dipped Waffle Cone
# 29921         "ICE CREAM" Earl Gray
# Name: name, Length: 29922, dtype: object

# %%
df[['order_id','name']]
# Out:
#        order_id                        name
# 0         10000    "ICE CREAM" Peanut Fudge
# 1         10000    "ICE CREAM" Peanut Fudge
# 2         10001          "SORBET" Raspberry
# 3         10001                         NaN
# 4         10001   "CONE" Dipped Waffle Cone
# ...         ...                         ...
# 29917     18452  "ICE CREAM" Dulce De Leche
# 29918     12889  "ICE CREAM" Dark Chocolate
# 29919     14526    "ICE CREAM" Peanut Fudge
# 29920     19589   "CONE" Dipped Waffle Cone
# 29921     19270       "ICE CREAM" Earl Gray
#
# [29922 rows x 2 columns]

# %%
df.sort_values(['name'])
# Out:
#        order_id                 name           ordered_at  price  quantity  \
# 8871      12966  "BEVERAGE" Espresso  2018-03-04 22:45:41  $2.50         1
# 8618      12881  "BEVERAGE" Espresso  2018-03-03 06:22:56  $2.50         1
# 28745     19624  "BEVERAGE" Espresso  2018-07-21 02:36:15  $2.50         2
# 11806     13941  "BEVERAGE" Espresso  2018-03-24 20:36:55  $2.50         1
# 23056     17727  "BEVERAGE" Espresso  2018-06-11 14:50:07  $2.50         2
# ...         ...                  ...                  ...    ...       ...
# 29737     19964                  NaN  2018-07-28 04:39:28  $2.50         3
# 29753     19970                  NaN  2018-07-28 06:36:42  $3.50         3
# 29802     19991                  NaN  2018-07-28 15:48:47  $1.50         3
# 29809     19994                  NaN  2018-07-28 17:17:29  $1.50         3
# 29881     15168                  NaN  2018-04-18 09:21:53  $2.50         1
#
#       line_total
# 8871       $2.50
# 8618       $2.50
# ...

# %%
df['name'].value_counts()
# Out:
# "ICE CREAM" Mint Chip             1131
# "SORBET" Lemon                    1113
# "ICE CREAM" Candied Bacon         1110
# "ICE CREAM" Dark Chocolate        1092
# "CONE" Sugar Cone                 1086
# "ICE CREAM" Double Fudge Chunk    1081
# "CONE" Cookie Cone                1080
# "SORBET" Raspberry                1077
# "ICE CREAM" Rocky Road            1077
# "SORBET" Blood Orange             1062
# "CONE" Dipped Waffle Cone         1061
# "ICE CREAM" Maple Brown Sugar     1054
# "BEVERAGE" Iced Coffee            1053
# "ICE CREAM" Dulce De Leche        1052
# "ICE CREAM" Wildberry             1051
# "CONE" Brownie Cone               1048
# "ICE CREAM" Vanilla Bean          1044
# "ICE CREAM" Matcha                1035
# "SORBET" Lychee                   1029
# "BEVERAGE" Espresso               1026
# "SORBET" Watermelon               1024
# "ICE CREAM" Earl Gray             1023
# "ICE CREAM" Strawberry            1020
# "ICE CREAM" Peanut Fudge          1010
# ...

# %%
names = df['name'].value_counts()

# %%
names.plot(kind='bar')
# Out:
# <AxesSubplot:>
